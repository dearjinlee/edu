# %%
import os
import argparse
import gc
import warnings
warnings.filterwarnings('ignore')

# %%
# for tensorflow v2.1
import tensorflow as tf
from tensorflow.keras import layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, ReduceLROnPlateau
from tensorflow.keras.utils import get_custom_objects

import numpy as np
import pandas as pd
import datetime

# %%
gc.collect()
# Out:
# 22

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 6 Physical GPUs, 6 Logical GPUs

# %%
# Output produced by the experiment (summaries, checkpoints etc.) has to be placed in this folder.
EXPERIMENT_OUTPUT_PATH = "/mnt/output/experiment"
MODEL_VERSION = 1

# %%
def gelu(x):
  return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))

# %%
get_custom_objects().update({'gelu': Activation(gelu)})

# %%
model = Sequential([
  Dense(units=1024, activation='gelu', input_dim=226),
  Dense(units=900, activation='gelu'),
  Dropout(0.02),
  Dense(units=1024, activation='gelu'),
  Dense(units=512, activation='gelu'),
  Dense(units=512, activation='gelu'),
  Dense(units=4, activation='linear')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              232448
# _________________________________________________________________
# dense_1 (Dense)              (None, 900)               922500
# _________________________________________________________________
# dropout (Dropout)            (None, 900)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              922624
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 2,867,080
# Trainable params: 2,867,080
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델을 컴파일합니다.
model.compile(loss='mae', optimizer='adam', metrics=['mae'])

# %%
# callbacks
def callbacks(path):
  model_chk_path = os.path.join(path, 'checkpoints', 'model.ckpt')
  tb_path = os.path.join(path, 'tensorboard')
  checkpoint = tf.keras.callbacks.ModelCheckpoint(
    model_chk_path,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=True
  )

  tensorboard = tf.keras.callbacks.TensorBoard(
    log_dir=tb_path,
    histogram_freq=0,
    write_graph=True,
    write_images=True,
  )

  reduce_lr = ReduceLROnPlateau(
    monitor='loss',
    factor=0.1,
    patience=10,
    verbose=1,
    mode='auto',
    # epsilon=1e-04,
    min_delta=1e-04,
    cooldown=0,
    min_lr=0
  )

  callback_list = [checkpoint, tensorboard, reduce_lr]
  return callback_list

# %%
import os

# %%
train_model_dir = '/mnt/output/experiment/model'
os.makedirs(train_model_dir, exist_ok=True)

# %%
callback_params = callbacks(train_model_dir)

# %%
# NUC에서 epoch 당 145초
# 5 epoch : mae = 15.1 (12분)
# 10 epoch : mae = 6.8 (24분)
# 15 epoch : mae = 4.5 (36분)
# 20 epoch : mae = 3.5 (48분)

epoch_num = 300
batch_size = 2000

# %%
# !pwd
# Out:
# /mnt/output/experiment

# %%
data_dir='/mnt/input/root/public/data/thin-film/'
train_data = data_dir + 'train-splited.csv'

import pandas as pd

train_splited = pd.read_csv(train_data)

# %%
#독립변수와 종속변수를 분리합니다.
train_X = train_splited.iloc[:, 5:]
train_Y = train_splited.iloc[:, 1:5]

model.fit(
    train_X, train_Y, 
    epochs=epoch_num, 
    batch_size=batch_size, 
    validation_split=0.05, 
    callbacks=callback_params
)
# Out:
# Train on 761805 samples, validate on 40095 samples
# Epoch 1/300
#   2000/761805 [..............................] - ETA: 14:17 - loss: 156.2101 - mae: 156.2101WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.555804). Check your callbacks.
# 756000/761805 [============================>.] - ETA: 0s - loss: 65.4002 - mae: 65.4002
# Epoch 00001: val_loss improved from inf to 52.78532, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 10s 13us/sample - loss: 65.3025 - mae: 65.3025 - val_loss: 52.7853 - val_mae: 52.7853
# Epoch 2/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 44.3481 - mae: 44.3481
# Epoch 00002: val_loss improved from 52.78532 to 35.43161, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 44.3036 - mae: 44.3036 - val_loss: 35.4316 - val_mae: 35.4316
# Epoch 3/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 28.3280 - mae: 28.3280
# Epoch 00003: val_loss improved from 35.43161 to 21.77117, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 7s 10us/sample - loss: 28.2819 - mae: 28.2819 - val_loss: 21.7712 - val_mae: 21.7712
# Epoch 4/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 19.2549 - mae: 19.2549
# Epoch 00004: val_loss improved from 21.77117 to 15.56564, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 19.2332 - mae: 19.2332 - val_loss: 15.5656 - val_mae: 15.5656
# Epoch 5/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 14.6333 - mae: 14.6333
# Epoch 00005: val_loss improved from 15.56564 to 12.88593, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 7s 9us/sample - loss: 14.6309 - mae: 14.6309 - val_loss: 12.8859 - val_mae: 12.8859
# Epoch 6/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 11.7801 - mae: 11.7801
# Epoch 00006: val_loss improved from 12.88593 to 9.89099, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 7s 9us/sample - loss: 11.7735 - mae: 11.7735 - val_loss: 9.8910 - val_mae: 9.8910
# Epoch 7/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 9.7926 - mae: 9.7926
# Epoch 00007: val_loss improved from 9.89099 to 8.78206, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 9.7895 - mae: 9.7895 - val_loss: 8.7821 - val_mae: 8.7821
# Epoch 8/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 8.4440 - mae: 8.4440
# Epoch 00008: val_loss improved from 8.78206 to 7.15151, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 8.4395 - mae: 8.4395 - val_loss: 7.1515 - val_mae: 7.1515
# Epoch 9/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 7.4060 - mae: 7.4060
# Epoch 00009: val_loss improved from 7.15151 to 7.05613, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 9us/sample - loss: 7.4061 - mae: 7.4061 - val_loss: 7.0561 - val_mae: 7.0561
# Epoch 10/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 6.5746 - mae: 6.5746
# Epoch 00010: val_loss improved from 7.05613 to 6.28118, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 7s 9us/sample - loss: 6.5744 - mae: 6.5744 - val_loss: 6.2812 - val_mae: 6.2812
# Epoch 11/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 5.9494 - mae: 5.9494
# Epoch 00011: val_loss improved from 6.28118 to 5.05210, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 5.9434 - mae: 5.9434 - val_loss: 5.0521 - val_mae: 5.0521
# Epoch 12/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 5.5048 - mae: 5.5048
# Epoch 00012: val_loss improved from 5.05210 to 5.04536, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 5.5028 - mae: 5.5028 - val_loss: 5.0454 - val_mae: 5.0454
# Epoch 13/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 5.0534 - mae: 5.0534
# Epoch 00013: val_loss improved from 5.04536 to 4.72517, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 5.0511 - mae: 5.0511 - val_loss: 4.7252 - val_mae: 4.7252
# Epoch 14/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 4.6425 - mae: 4.6425
# Epoch 00014: val_loss improved from 4.72517 to 4.32598, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 4.6424 - mae: 4.6424 - val_loss: 4.3260 - val_mae: 4.3260
# Epoch 15/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 4.3435 - mae: 4.3435
# Epoch 00015: val_loss improved from 4.32598 to 3.78754, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 4.3430 - mae: 4.3430 - val_loss: 3.7875 - val_mae: 3.7875
# Epoch 16/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 4.0797 - mae: 4.0797
# Epoch 00016: val_loss improved from 3.78754 to 3.71354, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 4.0789 - mae: 4.0789 - val_loss: 3.7135 - val_mae: 3.7135
# Epoch 17/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 3.8490 - mae: 3.8490
# Epoch 00017: val_loss improved from 3.71354 to 3.66969, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 3.8481 - mae: 3.8481 - val_loss: 3.6697 - val_mae: 3.6697
# Epoch 18/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 3.6550 - mae: 3.6550
# Epoch 00018: val_loss improved from 3.66969 to 3.22850, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 3.6543 - mae: 3.6543 - val_loss: 3.2285 - val_mae: 3.2285
# Epoch 19/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 3.4542 - mae: 3.4542
# Epoch 00019: val_loss improved from 3.22850 to 3.07846, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 3.4530 - mae: 3.4530 - val_loss: 3.0785 - val_mae: 3.0785
# Epoch 20/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 3.3506 - mae: 3.3506
# Epoch 00020: val_loss improved from 3.07846 to 2.89257, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 3.3469 - mae: 3.3469 - val_loss: 2.8926 - val_mae: 2.8926
# Epoch 21/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 3.1869 - mae: 3.1869
# Epoch 00021: val_loss did not improve from 2.89257
# 761805/761805 [==============================] - 6s 8us/sample - loss: 3.1873 - mae: 3.1873 - val_loss: 2.9741 - val_mae: 2.9741
# Epoch 22/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 3.0269 - mae: 3.0269
# Epoch 00022: val_loss improved from 2.89257 to 2.71228, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 3.0265 - mae: 3.0265 - val_loss: 2.7123 - val_mae: 2.7123
# Epoch 23/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 2.9075 - mae: 2.9075
# Epoch 00023: val_loss did not improve from 2.71228
# 761805/761805 [==============================] - 5s 7us/sample - loss: 2.9074 - mae: 2.9074 - val_loss: 2.9123 - val_mae: 2.9123
# Epoch 24/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 2.8362 - mae: 2.8362
# Epoch 00024: val_loss improved from 2.71228 to 2.56865, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 2.8356 - mae: 2.8356 - val_loss: 2.5686 - val_mae: 2.5686
# Epoch 25/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 2.7175 - mae: 2.7175
# Epoch 00025: val_loss improved from 2.56865 to 2.55489, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 2.7180 - mae: 2.7180 - val_loss: 2.5549 - val_mae: 2.5549
# Epoch 26/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 2.6493 - mae: 2.6493
# Epoch 00026: val_loss improved from 2.55489 to 2.42103, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 2.6492 - mae: 2.6492 - val_loss: 2.4210 - val_mae: 2.4210
# Epoch 27/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 2.5660 - mae: 2.5660
# Epoch 00027: val_loss did not improve from 2.42103
# 761805/761805 [==============================] - 5s 7us/sample - loss: 2.5670 - mae: 2.5670 - val_loss: 2.6558 - val_mae: 2.6558
# Epoch 28/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 2.4746 - mae: 2.4746
# Epoch 00028: val_loss improved from 2.42103 to 2.30639, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 2.4744 - mae: 2.4744 - val_loss: 2.3064 - val_mae: 2.3064
# Epoch 29/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 2.4334 - mae: 2.4334
# Epoch 00029: val_loss did not improve from 2.30639
# 761805/761805 [==============================] - 5s 7us/sample - loss: 2.4334 - mae: 2.4334 - val_loss: 2.3167 - val_mae: 2.3167
# Epoch 30/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 2.3710 - mae: 2.3710
# Epoch 00030: val_loss improved from 2.30639 to 2.15010, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 2.3690 - mae: 2.3690 - val_loss: 2.1501 - val_mae: 2.1501
# Epoch 31/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 2.3047 - mae: 2.3047
# Epoch 00031: val_loss improved from 2.15010 to 2.06106, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 2.3044 - mae: 2.3044 - val_loss: 2.0611 - val_mae: 2.0611
# Epoch 32/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 2.2684 - mae: 2.2684
# Epoch 00032: val_loss did not improve from 2.06106
# 761805/761805 [==============================] - 5s 7us/sample - loss: 2.2683 - mae: 2.2683 - val_loss: 2.2763 - val_mae: 2.2763
# Epoch 33/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 2.2272 - mae: 2.2272
# Epoch 00033: val_loss improved from 2.06106 to 2.01083, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 2.2262 - mae: 2.2262 - val_loss: 2.0108 - val_mae: 2.0108
# Epoch 34/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 2.1585 - mae: 2.1585
# Epoch 00034: val_loss did not improve from 2.01083
# 761805/761805 [==============================] - 5s 7us/sample - loss: 2.1588 - mae: 2.1588 - val_loss: 2.0554 - val_mae: 2.0554
# Epoch 35/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 2.1302 - mae: 2.1302
# Epoch 00035: val_loss improved from 2.01083 to 2.00829, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 2.1294 - mae: 2.1294 - val_loss: 2.0083 - val_mae: 2.0083
# Epoch 36/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 2.1027 - mae: 2.1027
# Epoch 00036: val_loss improved from 2.00829 to 1.99652, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 2.1029 - mae: 2.1029 - val_loss: 1.9965 - val_mae: 1.9965
# Epoch 37/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 2.0632 - mae: 2.0632
# Epoch 00037: val_loss improved from 1.99652 to 1.90740, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 2.0637 - mae: 2.0637 - val_loss: 1.9074 - val_mae: 1.9074
# Epoch 38/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 2.0082 - mae: 2.0082
# Epoch 00038: val_loss improved from 1.90740 to 1.79083, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 2.0079 - mae: 2.0079 - val_loss: 1.7908 - val_mae: 1.7908
# Epoch 39/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.9774 - mae: 1.9774
# Epoch 00039: val_loss did not improve from 1.79083
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.9775 - mae: 1.9775 - val_loss: 1.9007 - val_mae: 1.9007
# Epoch 40/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.9393 - mae: 1.9393
# Epoch 00040: val_loss did not improve from 1.79083
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.9401 - mae: 1.9401 - val_loss: 1.8764 - val_mae: 1.8764
# Epoch 41/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.9408 - mae: 1.9408
# Epoch 00041: val_loss did not improve from 1.79083
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.9419 - mae: 1.9419 - val_loss: 1.8140 - val_mae: 1.8140
# Epoch 42/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.9040 - mae: 1.9040
# Epoch 00042: val_loss did not improve from 1.79083
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.9042 - mae: 1.9042 - val_loss: 1.8638 - val_mae: 1.8638
# Epoch 43/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.8671 - mae: 1.8671
# Epoch 00043: val_loss improved from 1.79083 to 1.73413, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.8675 - mae: 1.8675 - val_loss: 1.7341 - val_mae: 1.7341
# Epoch 44/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.8491 - mae: 1.8491
# Epoch 00044: val_loss did not improve from 1.73413
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.8496 - mae: 1.8496 - val_loss: 1.8219 - val_mae: 1.8219
# Epoch 45/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.8119 - mae: 1.8119
# Epoch 00045: val_loss improved from 1.73413 to 1.71608, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.8114 - mae: 1.8114 - val_loss: 1.7161 - val_mae: 1.7161
# Epoch 46/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.7904 - mae: 1.7904
# Epoch 00046: val_loss improved from 1.71608 to 1.68661, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.7904 - mae: 1.7904 - val_loss: 1.6866 - val_mae: 1.6866
# Epoch 47/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.7753 - mae: 1.7753
# Epoch 00047: val_loss did not improve from 1.68661
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.7756 - mae: 1.7756 - val_loss: 1.7079 - val_mae: 1.7079
# Epoch 48/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.7430 - mae: 1.7430
# Epoch 00048: val_loss did not improve from 1.68661
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.7440 - mae: 1.7440 - val_loss: 1.8842 - val_mae: 1.8842
# Epoch 49/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.7452 - mae: 1.7452
# Epoch 00049: val_loss improved from 1.68661 to 1.63347, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.7449 - mae: 1.7449 - val_loss: 1.6335 - val_mae: 1.6335
# Epoch 50/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.7089 - mae: 1.7089
# Epoch 00050: val_loss did not improve from 1.63347
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.7088 - mae: 1.7088 - val_loss: 1.6596 - val_mae: 1.6596
# Epoch 51/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.6878 - mae: 1.6878
# Epoch 00051: val_loss did not improve from 1.63347
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.6889 - mae: 1.6889 - val_loss: 1.8216 - val_mae: 1.8216
# Epoch 52/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.7001 - mae: 1.7001
# Epoch 00052: val_loss improved from 1.63347 to 1.49518, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.6990 - mae: 1.6990 - val_loss: 1.4952 - val_mae: 1.4952
# Epoch 53/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.6685 - mae: 1.6685
# Epoch 00053: val_loss did not improve from 1.49518
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.6688 - mae: 1.6688 - val_loss: 1.5887 - val_mae: 1.5887
# Epoch 54/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.6310 - mae: 1.6309
# Epoch 00054: val_loss did not improve from 1.49518
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.6307 - mae: 1.6307 - val_loss: 1.5614 - val_mae: 1.5614
# Epoch 55/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.6250 - mae: 1.6250
# Epoch 00055: val_loss did not improve from 1.49518
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.6264 - mae: 1.6264 - val_loss: 1.5425 - val_mae: 1.5425
# Epoch 56/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.6413 - mae: 1.6413
# Epoch 00056: val_loss improved from 1.49518 to 1.42519, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.6400 - mae: 1.6400 - val_loss: 1.4252 - val_mae: 1.4252
# Epoch 57/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.5941 - mae: 1.5941
# Epoch 00057: val_loss did not improve from 1.42519
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5939 - mae: 1.5939 - val_loss: 1.5257 - val_mae: 1.5257
# Epoch 58/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.5860 - mae: 1.5860
# Epoch 00058: val_loss did not improve from 1.42519
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5851 - mae: 1.5851 - val_loss: 1.6552 - val_mae: 1.6552
# Epoch 59/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.5671 - mae: 1.5671
# Epoch 00059: val_loss improved from 1.42519 to 1.41216, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5668 - mae: 1.5668 - val_loss: 1.4122 - val_mae: 1.4122
# Epoch 60/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.5355 - mae: 1.5355
# Epoch 00060: val_loss did not improve from 1.41216
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5361 - mae: 1.5361 - val_loss: 1.4814 - val_mae: 1.4814
# Epoch 61/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.5503 - mae: 1.5503
# Epoch 00061: val_loss did not improve from 1.41216
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5503 - mae: 1.5503 - val_loss: 1.5854 - val_mae: 1.5854
# Epoch 62/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.5342 - mae: 1.5342
# Epoch 00062: val_loss did not improve from 1.41216
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5342 - mae: 1.5342 - val_loss: 1.7249 - val_mae: 1.7249
# Epoch 63/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.5153 - mae: 1.5153
# Epoch 00063: val_loss did not improve from 1.41216
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5148 - mae: 1.5148 - val_loss: 1.4818 - val_mae: 1.4818
# Epoch 64/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.5081 - mae: 1.5081
# Epoch 00064: val_loss did not improve from 1.41216
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5079 - mae: 1.5079 - val_loss: 1.4662 - val_mae: 1.4662
# Epoch 65/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.5285 - mae: 1.5285
# Epoch 00065: val_loss did not improve from 1.41216
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.5298 - mae: 1.5298 - val_loss: 1.5744 - val_mae: 1.5744
# Epoch 66/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.4806 - mae: 1.4806
# Epoch 00066: val_loss improved from 1.41216 to 1.37206, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.4804 - mae: 1.4804 - val_loss: 1.3721 - val_mae: 1.3721
# Epoch 67/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.4777 - mae: 1.4777
# Epoch 00067: val_loss did not improve from 1.37206
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.4777 - mae: 1.4777 - val_loss: 1.6327 - val_mae: 1.6327
# Epoch 68/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.4603 - mae: 1.4603
# Epoch 00068: val_loss did not improve from 1.37206
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.4599 - mae: 1.4599 - val_loss: 1.4439 - val_mae: 1.4439
# Epoch 69/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.4684 - mae: 1.4684
# Epoch 00069: val_loss did not improve from 1.37206
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.4676 - mae: 1.4676 - val_loss: 1.4883 - val_mae: 1.4883
# Epoch 70/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.4567 - mae: 1.4567
# Epoch 00070: val_loss improved from 1.37206 to 1.32944, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.4566 - mae: 1.4566 - val_loss: 1.3294 - val_mae: 1.3294
# Epoch 71/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.4357 - mae: 1.4357
# Epoch 00071: val_loss did not improve from 1.32944
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.4356 - mae: 1.4356 - val_loss: 1.3377 - val_mae: 1.3377
# Epoch 72/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.4240 - mae: 1.4240
# Epoch 00072: val_loss did not improve from 1.32944
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.4240 - mae: 1.4240 - val_loss: 1.4829 - val_mae: 1.4829
# Epoch 73/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.4203 - mae: 1.4203
# Epoch 00073: val_loss did not improve from 1.32944
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.4207 - mae: 1.4207 - val_loss: 1.4083 - val_mae: 1.4083
# Epoch 74/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.4193 - mae: 1.4193
# Epoch 00074: val_loss did not improve from 1.32944
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.4197 - mae: 1.4197 - val_loss: 1.4803 - val_mae: 1.4803
# Epoch 75/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.3946 - mae: 1.3946
# Epoch 00075: val_loss improved from 1.32944 to 1.30114, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.3949 - mae: 1.3949 - val_loss: 1.3011 - val_mae: 1.3011
# Epoch 76/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.3950 - mae: 1.3950
# Epoch 00076: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3947 - mae: 1.3947 - val_loss: 1.3074 - val_mae: 1.3074
# Epoch 77/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.3809 - mae: 1.3809
# Epoch 00077: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3810 - mae: 1.3810 - val_loss: 1.3651 - val_mae: 1.3651
# Epoch 78/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.3734 - mae: 1.3734
# Epoch 00078: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3735 - mae: 1.3735 - val_loss: 1.3793 - val_mae: 1.3793
# Epoch 79/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.3891 - mae: 1.3891
# Epoch 00079: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3887 - mae: 1.3887 - val_loss: 1.3744 - val_mae: 1.3744
# Epoch 80/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.3760 - mae: 1.3760
# Epoch 00080: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3758 - mae: 1.3758 - val_loss: 1.3057 - val_mae: 1.3057
# Epoch 81/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.3468 - mae: 1.3468
# Epoch 00081: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3469 - mae: 1.3469 - val_loss: 1.3641 - val_mae: 1.3641
# Epoch 82/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.3549 - mae: 1.3549
# Epoch 00082: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3553 - mae: 1.3553 - val_loss: 1.3473 - val_mae: 1.3473
# Epoch 83/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.3579 - mae: 1.3579
# Epoch 00083: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 6us/sample - loss: 1.3589 - mae: 1.3589 - val_loss: 1.3933 - val_mae: 1.3933
# Epoch 84/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.3508 - mae: 1.3508
# Epoch 00084: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 6us/sample - loss: 1.3509 - mae: 1.3509 - val_loss: 1.3583 - val_mae: 1.3583
# Epoch 85/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.3314 - mae: 1.3314
# Epoch 00085: val_loss did not improve from 1.30114
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3317 - mae: 1.3317 - val_loss: 1.3711 - val_mae: 1.3711
# Epoch 86/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.3079 - mae: 1.3079
# Epoch 00086: val_loss improved from 1.30114 to 1.19666, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.3079 - mae: 1.3079 - val_loss: 1.1967 - val_mae: 1.1967
# Epoch 87/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.3085 - mae: 1.3085
# Epoch 00087: val_loss improved from 1.19666 to 1.19564, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.3086 - mae: 1.3086 - val_loss: 1.1956 - val_mae: 1.1956
# Epoch 88/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.2952 - mae: 1.2952
# Epoch 00088: val_loss did not improve from 1.19564
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2946 - mae: 1.2946 - val_loss: 1.2170 - val_mae: 1.2170
# Epoch 89/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.3111 - mae: 1.3111
# Epoch 00089: val_loss did not improve from 1.19564
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.3113 - mae: 1.3113 - val_loss: 1.2448 - val_mae: 1.2448
# Epoch 90/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.3118 - mae: 1.3118
# Epoch 00090: val_loss did not improve from 1.19564
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.3121 - mae: 1.3121 - val_loss: 1.2566 - val_mae: 1.2566
# Epoch 91/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.2823 - mae: 1.2823
# Epoch 00091: val_loss did not improve from 1.19564
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2825 - mae: 1.2825 - val_loss: 1.2880 - val_mae: 1.2880
# Epoch 92/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.2886 - mae: 1.2886
# Epoch 00092: val_loss did not improve from 1.19564
# 761805/761805 [==============================] - 5s 6us/sample - loss: 1.2885 - mae: 1.2885 - val_loss: 1.1958 - val_mae: 1.1958
# Epoch 93/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.2594 - mae: 1.2594
# Epoch 00093: val_loss improved from 1.19564 to 1.17022, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2588 - mae: 1.2588 - val_loss: 1.1702 - val_mae: 1.1702
# Epoch 94/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.2762 - mae: 1.2762
# Epoch 00094: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2763 - mae: 1.2763 - val_loss: 1.3300 - val_mae: 1.3300
# Epoch 95/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.2769 - mae: 1.2769
# Epoch 00095: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2769 - mae: 1.2769 - val_loss: 1.2323 - val_mae: 1.2323
# Epoch 96/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.2613 - mae: 1.2613
# Epoch 00096: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2612 - mae: 1.2612 - val_loss: 1.1921 - val_mae: 1.1921
# Epoch 97/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.2517 - mae: 1.2517
# Epoch 00097: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2520 - mae: 1.2520 - val_loss: 1.2157 - val_mae: 1.2157
# Epoch 98/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.2435 - mae: 1.2435
# Epoch 00098: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2436 - mae: 1.2436 - val_loss: 1.3036 - val_mae: 1.3036
# Epoch 99/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.2613 - mae: 1.2613
# Epoch 00099: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2617 - mae: 1.2617 - val_loss: 1.2661 - val_mae: 1.2661
# Epoch 100/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.2633 - mae: 1.2633
# Epoch 00100: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2630 - mae: 1.2630 - val_loss: 1.1994 - val_mae: 1.1994
# Epoch 101/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.2471 - mae: 1.2471
# Epoch 00101: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2471 - mae: 1.2471 - val_loss: 1.2239 - val_mae: 1.2239
# Epoch 102/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.2157 - mae: 1.2157
# Epoch 00102: val_loss did not improve from 1.17022
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2165 - mae: 1.2165 - val_loss: 1.1831 - val_mae: 1.1831
# Epoch 103/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.2221 - mae: 1.2221
# Epoch 00103: val_loss improved from 1.17022 to 1.16207, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 7s 9us/sample - loss: 1.2222 - mae: 1.2222 - val_loss: 1.1621 - val_mae: 1.1621
# Epoch 104/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.2655 - mae: 1.2655
# Epoch 00104: val_loss did not improve from 1.16207
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2664 - mae: 1.2664 - val_loss: 1.2473 - val_mae: 1.2473
# Epoch 105/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.2095 - mae: 1.2095
# Epoch 00105: val_loss improved from 1.16207 to 1.13162, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.2091 - mae: 1.2091 - val_loss: 1.1316 - val_mae: 1.1316
# Epoch 106/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.2206 - mae: 1.2206
# Epoch 00106: val_loss did not improve from 1.13162
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2202 - mae: 1.2202 - val_loss: 1.1470 - val_mae: 1.1470
# Epoch 107/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.2103 - mae: 1.2103
# Epoch 00107: val_loss did not improve from 1.13162
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2104 - mae: 1.2104 - val_loss: 1.1661 - val_mae: 1.1661
# Epoch 108/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.2137 - mae: 1.2137
# Epoch 00108: val_loss did not improve from 1.13162
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2140 - mae: 1.2140 - val_loss: 1.1835 - val_mae: 1.1835
# Epoch 109/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.2095 - mae: 1.2095
# Epoch 00109: val_loss did not improve from 1.13162
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2098 - mae: 1.2098 - val_loss: 1.1382 - val_mae: 1.1382
# Epoch 110/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.1876 - mae: 1.1876
# Epoch 00110: val_loss did not improve from 1.13162
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1878 - mae: 1.1878 - val_loss: 1.2753 - val_mae: 1.2753
# Epoch 111/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.1884 - mae: 1.1884
# Epoch 00111: val_loss improved from 1.13162 to 1.08693, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.1883 - mae: 1.1883 - val_loss: 1.0869 - val_mae: 1.0869
# Epoch 112/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.2008 - mae: 1.2008
# Epoch 00112: val_loss did not improve from 1.08693
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2007 - mae: 1.2007 - val_loss: 1.1843 - val_mae: 1.1843
# Epoch 113/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.1894 - mae: 1.1894
# Epoch 00113: val_loss did not improve from 1.08693
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1894 - mae: 1.1894 - val_loss: 1.0957 - val_mae: 1.0957
# Epoch 114/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1565 - mae: 1.1565
# Epoch 00114: val_loss did not improve from 1.08693
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1566 - mae: 1.1566 - val_loss: 1.1492 - val_mae: 1.1492
# Epoch 115/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.1699 - mae: 1.1699
# Epoch 00115: val_loss did not improve from 1.08693
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1701 - mae: 1.1701 - val_loss: 1.2532 - val_mae: 1.2532
# Epoch 116/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.1701 - mae: 1.1701
# Epoch 00116: val_loss did not improve from 1.08693
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1702 - mae: 1.1702 - val_loss: 1.1504 - val_mae: 1.1504
# Epoch 117/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.2150 - mae: 1.2150
# Epoch 00117: val_loss did not improve from 1.08693
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.2150 - mae: 1.2150 - val_loss: 1.2024 - val_mae: 1.2024
# Epoch 118/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.1551 - mae: 1.1551
# Epoch 00118: val_loss improved from 1.08693 to 1.02923, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.1549 - mae: 1.1549 - val_loss: 1.0292 - val_mae: 1.0292
# Epoch 119/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1598 - mae: 1.1598
# Epoch 00119: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1595 - mae: 1.1595 - val_loss: 1.1036 - val_mae: 1.1036
# Epoch 120/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.1583 - mae: 1.1583
# Epoch 00120: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 6us/sample - loss: 1.1583 - mae: 1.1583 - val_loss: 1.1481 - val_mae: 1.1481
# Epoch 121/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.1706 - mae: 1.1706
# Epoch 00121: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1707 - mae: 1.1707 - val_loss: 1.3209 - val_mae: 1.3209
# Epoch 122/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.1438 - mae: 1.1438
# Epoch 00122: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1437 - mae: 1.1437 - val_loss: 1.0733 - val_mae: 1.0733
# Epoch 123/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1606 - mae: 1.1606
# Epoch 00123: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1606 - mae: 1.1606 - val_loss: 1.0805 - val_mae: 1.0805
# Epoch 124/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1351 - mae: 1.1351
# Epoch 00124: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1349 - mae: 1.1349 - val_loss: 1.1063 - val_mae: 1.1063
# Epoch 125/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.1450 - mae: 1.1450
# Epoch 00125: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 6us/sample - loss: 1.1451 - mae: 1.1451 - val_loss: 1.0932 - val_mae: 1.0932
# Epoch 126/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1471 - mae: 1.1471
# Epoch 00126: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1476 - mae: 1.1476 - val_loss: 1.1272 - val_mae: 1.1272
# Epoch 127/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.1588 - mae: 1.1588
# Epoch 00127: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1588 - mae: 1.1588 - val_loss: 1.1134 - val_mae: 1.1134
# Epoch 128/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.1236 - mae: 1.1236
# Epoch 00128: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1234 - mae: 1.1234 - val_loss: 1.0939 - val_mae: 1.0939
# Epoch 129/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1135 - mae: 1.1135
# Epoch 00129: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1135 - mae: 1.1135 - val_loss: 1.0899 - val_mae: 1.0899
# Epoch 130/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.1408 - mae: 1.1408
# Epoch 00130: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1408 - mae: 1.1408 - val_loss: 1.0660 - val_mae: 1.0660
# Epoch 131/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1322 - mae: 1.1322
# Epoch 00131: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1324 - mae: 1.1324 - val_loss: 1.0887 - val_mae: 1.0887
# Epoch 132/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1302 - mae: 1.1302
# Epoch 00132: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1299 - mae: 1.1299 - val_loss: 1.0912 - val_mae: 1.0912
# Epoch 133/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1160 - mae: 1.1160
# Epoch 00133: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1169 - mae: 1.1169 - val_loss: 1.2795 - val_mae: 1.2795
# Epoch 134/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.1052 - mae: 1.1052
# Epoch 00134: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1052 - mae: 1.1052 - val_loss: 1.2110 - val_mae: 1.2110
# Epoch 135/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.1020 - mae: 1.1020
# Epoch 00135: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1021 - mae: 1.1021 - val_loss: 1.1021 - val_mae: 1.1021
# Epoch 136/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.1033 - mae: 1.1033
# Epoch 00136: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.1031 - mae: 1.1031 - val_loss: 1.0599 - val_mae: 1.0599
# Epoch 137/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.1117 - mae: 1.1117
# Epoch 00137: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.1116 - mae: 1.1116 - val_loss: 1.0796 - val_mae: 1.0796
# Epoch 138/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.1091 - mae: 1.1091
# Epoch 00138: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.1089 - mae: 1.1089 - val_loss: 1.1470 - val_mae: 1.1470
# Epoch 139/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.1121 - mae: 1.1121
# Epoch 00139: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.1116 - mae: 1.1116 - val_loss: 1.1567 - val_mae: 1.1567
# Epoch 140/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.1262 - mae: 1.1262
# Epoch 00140: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.1269 - mae: 1.1269 - val_loss: 1.1027 - val_mae: 1.1027
# Epoch 141/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0889 - mae: 1.0889
# Epoch 00141: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.0889 - mae: 1.0889 - val_loss: 1.1272 - val_mae: 1.1272
# Epoch 142/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.0980 - mae: 1.0980
# Epoch 00142: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.0977 - mae: 1.0977 - val_loss: 1.1493 - val_mae: 1.1493
# Epoch 143/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.0859 - mae: 1.0859
# Epoch 00143: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0858 - mae: 1.0858 - val_loss: 1.1461 - val_mae: 1.1461
# Epoch 144/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.1181 - mae: 1.1181
# Epoch 00144: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.1183 - mae: 1.1183 - val_loss: 1.0588 - val_mae: 1.0588
# Epoch 145/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.1004 - mae: 1.1004
# Epoch 00145: val_loss did not improve from 1.02923
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.1001 - mae: 1.1001 - val_loss: 1.0491 - val_mae: 1.0491
# Epoch 146/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.0673 - mae: 1.0673
# Epoch 00146: val_loss improved from 1.02923 to 0.96170, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 7us/sample - loss: 1.0672 - mae: 1.0672 - val_loss: 0.9617 - val_mae: 0.9617
# Epoch 147/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0651 - mae: 1.0651
# Epoch 00147: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0649 - mae: 1.0649 - val_loss: 0.9951 - val_mae: 0.9951
# Epoch 148/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0640 - mae: 1.0640
# Epoch 00148: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0643 - mae: 1.0643 - val_loss: 1.0908 - val_mae: 1.0908
# Epoch 149/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.0729 - mae: 1.0729
# Epoch 00149: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0727 - mae: 1.0727 - val_loss: 1.0059 - val_mae: 1.0059
# Epoch 150/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.0640 - mae: 1.0640
# Epoch 00150: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0642 - mae: 1.0642 - val_loss: 1.1288 - val_mae: 1.1288
# Epoch 151/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.0573 - mae: 1.0573
# Epoch 00151: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0574 - mae: 1.0574 - val_loss: 1.0392 - val_mae: 1.0392
# Epoch 152/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.0920 - mae: 1.0920
# Epoch 00152: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0920 - mae: 1.0920 - val_loss: 1.0638 - val_mae: 1.0638
# Epoch 153/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0698 - mae: 1.0698
# Epoch 00153: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0703 - mae: 1.0703 - val_loss: 1.0963 - val_mae: 1.0963
# Epoch 154/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.0678 - mae: 1.0678
# Epoch 00154: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0680 - mae: 1.0680 - val_loss: 1.1515 - val_mae: 1.1515
# Epoch 155/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.0771 - mae: 1.0771
# Epoch 00155: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0786 - mae: 1.0786 - val_loss: 1.0127 - val_mae: 1.0127
# Epoch 156/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.0651 - mae: 1.0651
# Epoch 00156: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0649 - mae: 1.0649 - val_loss: 1.0435 - val_mae: 1.0435
# Epoch 157/300
# 754000/761805 [============================>.] - ETA: 0s - loss: 1.0554 - mae: 1.0554
# Epoch 00157: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0551 - mae: 1.0551 - val_loss: 1.0086 - val_mae: 1.0086
# Epoch 158/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0532 - mae: 1.0532
# Epoch 00158: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0533 - mae: 1.0533 - val_loss: 1.0530 - val_mae: 1.0530
# Epoch 159/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.0807 - mae: 1.0807
# Epoch 00159: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0806 - mae: 1.0806 - val_loss: 1.0420 - val_mae: 1.0420
# Epoch 160/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0363 - mae: 1.0363
# Epoch 00160: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0362 - mae: 1.0362 - val_loss: 1.0896 - val_mae: 1.0896
# Epoch 161/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0454 - mae: 1.0454
# Epoch 00161: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0459 - mae: 1.0459 - val_loss: 0.9876 - val_mae: 0.9876
# Epoch 162/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.0411 - mae: 1.0411
# Epoch 00162: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0411 - mae: 1.0411 - val_loss: 1.0534 - val_mae: 1.0534
# Epoch 163/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0615 - mae: 1.0615
# Epoch 00163: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0613 - mae: 1.0613 - val_loss: 1.0390 - val_mae: 1.0390
# Epoch 164/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.0420 - mae: 1.0420
# Epoch 00164: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0419 - mae: 1.0419 - val_loss: 1.0146 - val_mae: 1.0146
# Epoch 165/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0412 - mae: 1.0412
# Epoch 00165: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0415 - mae: 1.0415 - val_loss: 1.0530 - val_mae: 1.0530
# Epoch 166/300
# 758000/761805 [============================>.] - ETA: 0s - loss: 1.0381 - mae: 1.0381
# Epoch 00166: val_loss did not improve from 0.96170
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0382 - mae: 1.0382 - val_loss: 1.0072 - val_mae: 1.0072
# Epoch 167/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.0398 - mae: 1.0398
# Epoch 00167: val_loss improved from 0.96170 to 0.95206, saving model to /mnt/output/experiment/model/checkpoints/model.ckpt
# 761805/761805 [==============================] - 6s 8us/sample - loss: 1.0397 - mae: 1.0397 - val_loss: 0.9521 - val_mae: 0.9521
# Epoch 168/300
# 760000/761805 [============================>.] - ETA: 0s - loss: 1.0236 - mae: 1.0236
# Epoch 00168: val_loss did not improve from 0.95206
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0238 - mae: 1.0238 - val_loss: 1.0206 - val_mae: 1.0206
# Epoch 169/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.0345 - mae: 1.0345
# Epoch 00169: val_loss did not improve from 0.95206
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0340 - mae: 1.0340 - val_loss: 0.9957 - val_mae: 0.9957
# Epoch 170/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.0372 - mae: 1.0372
# Epoch 00170: val_loss did not improve from 0.95206
# 761805/761805 [==============================] - 5s 6us/sample - loss: 1.0372 - mae: 1.0372 - val_loss: 1.0166 - val_mae: 1.0166
# Epoch 171/300
# 756000/761805 [============================>.] - ETA: 0s - loss: 1.0401 - mae: 1.0401
# Epoch 00171: val_loss did not improve from 0.95206
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0403 - mae: 1.0403 - val_loss: 0.9915 - val_mae: 0.9915
# Epoch 172/300
# 752000/761805 [============================>.] - ETA: 0s - loss: 1.0526 - mae: 1.0526
# Epoch 00172: val_loss did not improve from 0.95206
# 761805/761805 [==============================] - 5s 7us/sample - loss: 1.0523 - mae: 1.0523 - val_loss: 1.0875 - val_mae: 1.0875
# Epoch 173/300
# 246000/761805 [========>.....................] - ETA: 3s - loss: 1.0281 - mae: 1.0281

# %%
# model.fit(train_X, train_Y, epochs=epoch_num, batch_size=batch_size, validation_split=0.05, callbacks=callback_params)
